# %%
import pandas as pd 
df=pd.read_csv('designed_sgrnas.csv')
df.head()
# Out:
#              gene                spacer  pam strand  position  gc_percent  \
# 0  LOC_Os01g20160  GAAAACTAGCATGTCCTTTG  TGG      +        13        40.0
# 1  LOC_Os01g20160  GTGCGCGCTGATCCCCTTCC  CGG      +      3634        70.0
# 2  LOC_Os01g20160  TTACCTGATGATGACGACCA  TGG      -      3986        45.0
# 3  LOC_Os01g20160  TAGGAGAGAAATGAGTTCTC  TGG      -      4368        40.0
# 4  LOC_Os01g20160  GCTCAAAATGTAACCGAACG  AGG      -      2542        45.0
#
#    on_target  offtarget_count  final_score
# 0     0.6162                0       0.6162
# 1     0.6085                0       0.6085
# 2     0.5952                0       0.5952
# 3     0.5790                0       0.5790
# 4     0.5767                0       0.5767
